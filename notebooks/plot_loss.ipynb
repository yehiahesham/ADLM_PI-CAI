# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
loss = np.load("/u/home/seel/ADLM/adlm_ss2023_mmcl/results/picai/picai_Multmodal_Contrastive_lasso_orig_ResNet10_500e/train_loss.npy")
plt.plot(loss)

# %%
va_loss = np.load("/u/home/seel/ADLM/adlm_ss2023_mmcl/results/picai/picai_Multmodal_Contrastive_lasso_orig_ResNet10_500e/val_AUROC.npy")
plt.plot(loss)
